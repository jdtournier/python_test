# %% [markdown]
# # Title
#
# Something to check how to operate with Jupyter notebooks in Github Codespaces

# %%
print ('hello!')
# Out:
# hello!

# %% [markdown]
# ## here is a subsection
#
# I'm going to try the *following*:
# - fix A
# - break B
# - see what happens
#
#
# This corresponds to this code:
# ```python
# import numpy as np
# a = np.ndarray()
# ```

# %%
# In a Jupyter notebook cell
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# Data
x = np.linspace(0, 10, 100)
y = 2 * x + 1  # y = 2x + 1

# Plot
plt.figure(figsize=(10,4))
plt.plot(x, y, label='y = 2x + 1', color='tab:blue', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Simple Line Plot')
plt.show()
